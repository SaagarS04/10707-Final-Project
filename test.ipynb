# %%
from pybaseball import statcast
import pandas as pd
import numpy as np

# %%
for col in df.columns:
    print(col)
# Out:
# pitch_type
# game_date
# release_speed
# release_pos_x
# release_pos_z
# player_name
# batter
# pitcher
# events
# description
# spin_dir
# spin_rate_deprecated
# break_angle_deprecated
# break_length_deprecated
# zone
# des
# game_type
# stand
# p_throws
# home_team
# away_team
# type
# hit_location
# bb_type
# balls
# strikes
# game_year
# pfx_x
# pfx_z
# plate_x
# plate_z
# on_3b
# on_2b
# on_1b
# outs_when_up
# inning
# inning_topbot
# hc_x
# hc_y
# tfs_deprecated
# tfs_zulu_deprecated
# umpire
# sv_id
# vx0
# vy0
# vz0
# ax
# ay
# az
# sz_top
# sz_bot
# hit_distance_sc
# launch_speed
# launch_angle
# effective_speed
# release_spin_rate
# release_extension
# game_pk
# fielder_2
# fielder_3
# fielder_4
# fielder_5
# fielder_6
# fielder_7
# fielder_8
# fielder_9
# release_pos_y
# estimated_ba_using_speedangle
# estimated_woba_using_speedangle
# woba_value
# woba_denom
# babip_value
# iso_value
# launch_speed_angle
# at_bat_number
# pitch_number
# pitch_name
# home_score
# away_score
# bat_score
# fld_score
# post_away_score
# post_home_score
# post_bat_score
# post_fld_score
# if_fielding_alignment
# of_fielding_alignment
# spin_axis
# delta_home_win_exp
# delta_run_exp
# bat_speed
# swing_length
# estimated_slg_using_speedangle
# delta_pitcher_run_exp
# hyper_speed
# home_score_diff
# bat_score_diff
# home_win_exp
# bat_win_exp
# age_pit_legacy
# age_bat_legacy
# age_pit
# age_bat
# n_thruorder_pitcher
# n_priorpa_thisgame_player_at_bat
# pitcher_days_since_prev_game
# batter_days_since_prev_game
# pitcher_days_until_next_game
# batter_days_until_next_game
# api_break_z_with_gravity
# api_break_x_arm
# api_break_x_batter_in
# arm_angle
# attack_angle
# attack_direction
# swing_path_tilt
# intercept_ball_minus_batter_pos_x_inches
# intercept_ball_minus_batter_pos_y_inches

# %%
def get_transformed_data(start_dt, end_dt):
    df = statcast(start_dt = start_dt, end_dt = end_dt).sort_values(by=['game_date', 'at_bat_number'])
    play_results = df['events']
    pitch_results = df['description']
    home_team_win_target = (
        df.sort_values(['home_team', 'game_date', 'at_bat_number'])
        .groupby(['home_team', 'game_date'])['home_win_exp']
        .last()
        .pipe(np.round)
        )
    
    res_dict = {
        'Context': None,
        'Play by Play': None,
        'Pitch_target' : None,
        'Result_target' : None,
        'Game_target' : None
    }
# Out:
#      pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 2442         FF  2025-05-01           91.4          -1.37           5.14
# 2473         FF  2025-05-01           92.2          -1.41           5.15
# 2561         SI  2025-05-01           91.6          -1.43           5.12
# 2651         SI  2025-05-01           91.7          -1.58           5.02
# 2739         CU  2025-05-01           77.3          -1.51           5.33
# ...         ...         ...            ...            ...            ...
# 3571         FF  2025-05-10           94.9          -1.58            5.7
# 2763         FF  2025-05-10           95.6          -1.54           5.59
# 2545         FC  2025-05-10           88.1          -1.82           5.51
# 2582         FF  2025-05-10           94.8          -1.63           5.58
# 2669         FC  2025-05-10           86.7          -1.77           5.62
#
#         player_name  batter  pitcher     events      description  ...  \
# 2442    Lively, Ben  666397   594902  field_out    hit_into_play  ...
# 2473    Lively, Ben  666397   594902        NaN             foul  ...
# 2561    Lively, Ben  666397   594902        NaN             foul  ...
# 2651    Lively, Ben  666397   594902        NaN             ball  ...
# 2739    Lively, Ben  666397   594902        NaN             ball  ...
# ...             ...     ...      ...        ...              ...  ...
# 3571  Pagán, Emilio  701358   641941        NaN             ball  ...
# 2763  Pagán, Emilio  665161   641941     double    hit_into_play  ...
# 2545  Pagán, Emilio  663898   641941  strikeout  swinging_strike  ...
# 2582  Pagán, Emilio  663898   641941        NaN             foul  ...
# 2669  Pagán, Emilio  663898   641941        NaN  swinging_strike  ...
#
#       batter_days_until_next_game  api_break_z_with_gravity  api_break_x_arm  \
# 2442                            1                      1.71             1.08
# 2473                            1                      1.36             0.94
# 2561                            1                      1.88             1.21
# 2651                            1                       1.9             1.48
# 2739                            1                      4.16            -0.64
# ...                           ...                       ...              ...
# 3571                            1                      1.05             0.52
# 2763                            1                      0.88             0.82
# 2545                            1                      2.63            -0.46
# 2582                            1                      0.91             0.37
# 2669                            1                      2.74             -0.5
#
#       api_break_x_batter_in  arm_angle attack_angle attack_direction  \
# 2442                  -1.08       38.4    15.849379         5.163524
# 2473                  -0.94       40.9     5.155893         3.167203
# 2561                  -1.21       40.5    -2.828276        17.944346
# 2651                  -1.48       34.2         <NA>             <NA>
# 2739                   0.64       43.7         <NA>             <NA>
# ...                     ...        ...          ...              ...
# 3571                   0.52       42.1         <NA>             <NA>
# 2763                   0.82       42.0     15.84212       -18.354518
# 2545                  -0.46       45.4    19.723582        -24.68105
# 2582                   0.37       41.1     7.408551        -7.609833
# 2669                   -0.5       43.0    23.816753       -30.979234
#
#      swing_path_tilt intercept_ball_minus_batter_pos_x_inches  \
# 2442       37.579678                                41.961883
# 2473       45.518316                                33.153286
# 2561       51.351635                                 24.45473
# 2651            <NA>                                     <NA>
# 2739            <NA>                                     <NA>
# ...              ...                                      ...
# 3571            <NA>                                     <NA>
# 2763       35.431564                                31.574918
# 2545       33.068368                                42.560007
# 2582       39.478588                                42.055248
# 2669       32.148056                                38.404247
#
#      intercept_ball_minus_batter_pos_y_inches
# 2442                                28.489756
# 2473                                28.449989
# 2561                                24.043783
# 2651                                     <NA>
# 2739                                     <NA>
# ...                                       ...
# 3571                                     <NA>
# 2763                                37.307329
# 2545                                48.486111
# 2582                                28.518635
# 2669                                47.935558
#
# [39233 rows x 118 columns]

# %%
df.select_dtypes(str)
# Out:
#      pitch_type   game_date    player_name     events    description  \
# 2333         FF  2025-05-10  Jackson, Luke  strikeout  called_strike
# 2403         FF  2025-05-10  Jackson, Luke        NaN           foul
# 2534         SL  2025-05-10  Jackson, Luke        NaN           foul
# 2636         FF  2025-05-10  Jackson, Luke        NaN           ball
# 2731         SL  2025-05-10  Jackson, Luke        NaN       foul_tip
# ...         ...         ...            ...        ...            ...
# 2642         SL  2025-05-01    Burke, Sean        NaN  called_strike
# 2730         SL  2025-05-01    Burke, Sean        NaN           ball
# 2830         FF  2025-05-01    Burke, Sean        NaN           ball
# 2921         FF  2025-05-01    Burke, Sean        NaN           foul
# 3012         FF  2025-05-01    Burke, Sean        NaN           ball
#
#                                       des game_type stand p_throws home_team  \
# 2333  Trey Sweeney called out on strikes.         R     L        R       DET
# 2403                                 Foul         R     L        R       DET
# 2534                                 Foul         R     L        R       DET
# 2636                                 Ball         R     L        R       DET
# 2731                             Foul Tip         R     L        R       DET
# ...                                   ...       ...   ...      ...       ...
# 2642                        Called Strike         R     L        R       CWS
# 2730                                 Ball         R     L        R       CWS
# 2830                                 Ball         R     L        R       CWS
# 2921                                 Foul         R     L        R       CWS
# 3012                                 Ball         R     L        R       CWS
#
#      away_team type bb_type inning_topbot       pitch_name  \
# 2333       TEX    S     NaN           Bot  4-Seam Fastball
# 2403       TEX    S     NaN           Bot  4-Seam Fastball
# 2534       TEX    S     NaN           Bot           Slider
# 2636       TEX    B     NaN           Bot  4-Seam Fastball
# 2731       TEX    S     NaN           Bot           Slider
# ...        ...  ...     ...           ...              ...
# 2642       MIL    S     NaN           Top           Slider
# 2730       MIL    B     NaN           Top           Slider
# 2830       MIL    B     NaN           Top  4-Seam Fastball
# 2921       MIL    S     NaN           Top  4-Seam Fastball
# 3012       MIL    B     NaN           Top  4-Seam Fastball
#
#      if_fielding_alignment of_fielding_alignment
# 2333         Infield shade              Standard
# 2403         Infield shade              Standard
# 2534         Infield shade              Standard
# 2636         Infield shade              Standard
# 2731         Infield shade              Standard
# ...                    ...                   ...
# 2642              Standard              Standard
# 2730              Standard              Standard
# 2830              Standard              Standard
# 2921              Standard              Standard
# 3012              Standard              Standard
#
# [39233 rows x 17 columns]

# %%
result
# Out:
# home_team  game_date
# ATH        2025-05-05    1.0
#            2025-05-06    0.0
#            2025-05-07    0.0
#            2025-05-09    0.0
#            2025-05-10    1.0
#                         ...
# TOR        2025-05-04    0.0
# WSH        2025-05-06    1.0
#            2025-05-07    0.0
#            2025-05-09    0.0
#            2025-05-10    0.0
# Name: home_win_exp, Length: 131, dtype: Float64

# %%
df.sort_values(['home_team', 'game_date', 'at_bat_number']).groupby(['home_team', 'game_date'])['home_score_diff'].last()
# Out:
# <IntegerArray>
# [  0,  -2,  -1,  -8,   4,  -7,   1,  -6,   2,  -3,   3,  -4,  -5,   5,   7,
#   -9,   8,   6, -21,  10, -12, -10,   9]
# Length: 23, dtype: Int64

# %%
for col in df.columns:
    print(col)
# Out:
# pitch_type
# game_date
# release_speed
# release_pos_x
# release_pos_z
# player_name
# batter
# pitcher
# events
# description
# spin_dir
# spin_rate_deprecated
# break_angle_deprecated
# break_length_deprecated
# zone
# des
# game_type
# stand
# p_throws
# home_team
# away_team
# type
# hit_location
# bb_type
# balls
# strikes
# game_year
# pfx_x
# pfx_z
# plate_x
# plate_z
# on_3b
# on_2b
# on_1b
# outs_when_up
# inning
# inning_topbot
# hc_x
# hc_y
# tfs_deprecated
# tfs_zulu_deprecated
# umpire
# sv_id
# vx0
# vy0
# vz0
# ax
# ay
# az
# sz_top
# sz_bot
# hit_distance_sc
# launch_speed
# launch_angle
# effective_speed
# release_spin_rate
# release_extension
# game_pk
# fielder_2
# fielder_3
# fielder_4
# fielder_5
# fielder_6
# fielder_7
# fielder_8
# fielder_9
# release_pos_y
# estimated_ba_using_speedangle
# estimated_woba_using_speedangle
# woba_value
# woba_denom
# babip_value
# iso_value
# launch_speed_angle
# at_bat_number
# pitch_number
# pitch_name
# home_score
# away_score
# bat_score
# fld_score
# post_away_score
# post_home_score
# post_bat_score
# post_fld_score
# if_fielding_alignment
# of_fielding_alignment
# spin_axis
# delta_home_win_exp
# delta_run_exp
# bat_speed
# swing_length
# estimated_slg_using_speedangle
# delta_pitcher_run_exp
# hyper_speed
# home_score_diff
# bat_score_diff
# home_win_exp
# bat_win_exp
# age_pit_legacy
# age_bat_legacy
# age_pit
# age_bat
# n_thruorder_pitcher
# n_priorpa_thisgame_player_at_bat
# pitcher_days_since_prev_game
# batter_days_since_prev_game
# pitcher_days_until_next_game
# batter_days_until_next_game
# api_break_z_with_gravity
# api_break_x_arm
# api_break_x_batter_in
# arm_angle
# attack_angle
# attack_direction
# swing_path_tilt
# intercept_ball_minus_batter_pos_x_inches
# intercept_ball_minus_batter_pos_y_inches
